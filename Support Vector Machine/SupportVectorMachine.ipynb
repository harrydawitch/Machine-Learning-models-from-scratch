# %% [markdown]
# # **HEART DISEASE CLASSIFICATION**
# ## *About the dataset*
#
# *This dataset contain patient records and my job is to train a model to detect whether a patient have a heart disease*
#
# ### **Features**
#
# 1. Age: age of the patient [years]
#
# 2. Sex: sex of the patient [M: Male, F: Female]
#
# 3. ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
#
# 4. RestingBP: resting blood pressure [mm Hg]
#
# 5. Cholesterol: serum cholesterol [mm/dl]
#
# 6. FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]
#
# 7. RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]
#
# 8. MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
#
# 9. ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
#
# 10. Oldpeak: oldpeak = ST [Numeric value measured in depression]
#
# 11. ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
#
# 12. HeartDisease: output class [1: heart disease, 0: Normal]

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import joblib

# %% [markdown]
# ### **EXPLORATORY DATA ANALYSIS (EDA)**

# %%
# Read the data
data = pd.read_csv('Data\heart.csv')
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
data.describe(include= 'all')
# Out:
#                Age  Sex ChestPainType   RestingBP  Cholesterol   FastingBS  \
# count   918.000000  918           918  918.000000   918.000000  918.000000
# unique         NaN    2             4         NaN          NaN         NaN
# top            NaN    M           ASY         NaN          NaN         NaN
# freq           NaN  725           496         NaN          NaN         NaN
# mean     53.510893  NaN           NaN  132.396514   198.799564    0.233115
# std       9.432617  NaN           NaN   18.514154   109.384145    0.423046
# min      28.000000  NaN           NaN    0.000000     0.000000    0.000000
# 25%      47.000000  NaN           NaN  120.000000   173.250000    0.000000
# 50%      54.000000  NaN           NaN  130.000000   223.000000    0.000000
# 75%      60.000000  NaN           NaN  140.000000   267.000000    0.000000
# max      77.000000  NaN           NaN  200.000000   603.000000    1.000000
#
#        RestingECG       MaxHR ExerciseAngina     Oldpeak ST_Slope  \
# count         918  918.000000            918  918.000000      918
# unique          3         NaN              2         NaN        3
# top        Normal         NaN              N         NaN     Flat
# freq          552         NaN            547         NaN      460
# mean          NaN  136.809368            NaN    0.887364      NaN
# std           NaN   25.460334            NaN    1.066570      NaN
# min           NaN   60.000000            NaN   -2.600000      NaN
# 25%           NaN  120.000000            NaN    0.000000      NaN
# 50%           NaN  138.000000            NaN    0.600000      NaN
# 75%           NaN  156.000000            NaN    1.500000      NaN
# max           NaN  202.000000            NaN    6.200000      NaN
#
#         HeartDisease
# count     918.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.553377
# std         0.497414
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
print(f'Data info: {data.info()}\n\n')
print('-------------------------------')
print(f'Null values in data: {data.isna().sum()}')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB
# Data info: None
#
#
# -------------------------------
# Null values in data: Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# ### **DATA PREPROCESSING**

# %%
def preprocessing(data):
    # Convert binary features into 0 and 1
    binary_features = ['Sex', 'ExerciseAngina']
    for i in binary_features:
        data[i] = data[i].apply(lambda x: 1 if x in ['M', 'Y'] else 0)
    
    # Encoding features with more than 3 categories
    le = LabelEncoder()
    cat_features = ['ChestPainType', 'RestingECG', 'ST_Slope']
    for i in cat_features:
        data[i] = le.fit_transform(data[i])
    
    return data

data = preprocessing(data)

# %%
# Split data and scale it

X = data.drop('HeartDisease', axis= 1)
y = data.HeartDisease

# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size= 0.3, random_state= 42)

y_train = np.array(y_train)
y_test = np.array(y_test)

# %% [markdown]
# ### **MODELLING**

# %%
import numpy as np

class SVM:
    def __init__(self, alpha=0.01, regularization=0.001, iter=1000, print_cost=False):
        self.alpha = alpha
        self.lambda_ = regularization
        self.print_cost = print_cost
        self.iter = iter
        self.w = None
        self.b = None

    def fit(self, X, y):
        m, n = X.shape
        y_ = np.where(y <= 0, -1, 1)

        self.w = np.random.rand(n)
        self.b = np.random.rand()

        for _ in range(self.iter):
            for i, x_i in enumerate(X):
                condition = y_[i] * (np.dot(x_i, self.w) - self.b) >= 1
                if condition:
                    dw = 2 * self.lambda_ * self.w
                    db = 0
                else:
                    dw = 2 * self.lambda_ * self.w - np.dot(y_[i], x_i)
                    db = y_[i]

                self.w -= self.alpha * dw
                self.b -= self.alpha * db
            
            if self.print_cost and _ % 50 == 0:
                cost = self.cost(X, y)
                print(f'Cost at {_}: {cost}')

    def predict(self, X):
        y_preds = np.sign(np.dot(X, self.w) - self.b)
        return y_preds

    def score(self, X, y):
        y_preds = self.predict(X)
        return np.mean(y_preds == y)

    def cost(self, X, y):
        y_ = np.where(y <= 0, -1, 1)
        hinge_loss = np.maximum(0, 1 - y_ * (np.dot(X, self.w) - self.b))
        regularization_loss = self.lambda_ * np.sum(self.w ** 2)
        total_loss = np.mean(hinge_loss) + regularization_loss
        return total_loss

# %% [markdown]
# ### **TRAIN AND EVALUATE THE MODEL**

# %%
model = SVM(alpha=0.01, regularization=0.001, iter=3000)
model.fit(X_train, y_train)

# %%
print("Training Accuracy:", model.score(X_train, y_train))
print("Test Accuracy:", model.score(X_test, y_test))
# Out:
# Training Accuracy: 0.4672897196261682
# Test Accuracy: 0.5036231884057971

# %%
joblib.dump(model, 'SVM_model.pkl')

# %% [markdown]
# ### **USING SVM ON SCI-KIT LEARN**

# %%
from sklearn.svm import SVC
n = [i / 100.0 for i in range(1,100)]
for _ in n:
    model = SVC(kernel='rbf', gamma= _, random_state = 42)
    model.fit(X_train, y_train)

    print(f"Training Accuracy at gamma {_}: {model.score(X_train, y_train)}")
    print(f"Test Accuracy at gamma {_}: {model.score(X_test, y_test)}\n\n")
# Out:
# Training Accuracy at gamma 0.01: 0.8582554517133957
# Test Accuracy at gamma 0.01: 0.8731884057971014
#
#
# Training Accuracy at gamma 0.02: 0.8691588785046729
# Test Accuracy at gamma 0.02: 0.8840579710144928
#
#
# Training Accuracy at gamma 0.03: 0.8785046728971962
# Test Accuracy at gamma 0.03: 0.8840579710144928
#
#
# Training Accuracy at gamma 0.04: 0.8785046728971962
# Test Accuracy at gamma 0.04: 0.8840579710144928
#
#
# Training Accuracy at gamma 0.05: 0.883177570093458
# Test Accuracy at gamma 0.05: 0.8876811594202898
#
#
# Training Accuracy at gamma 0.06: 0.8847352024922118
# Test Accuracy at gamma 0.06: 0.8913043478260869
#
#
# Training Accuracy at gamma 0.07: 0.8862928348909658
# Test Accuracy at gamma 0.07: 0.8913043478260869
#
#
# Training Accuracy at gamma 0.08: 0.8878504672897196
# Test Accuracy at gamma 0.08: 0.8913043478260869
#
#
# Training Accuracy at gamma 0.09: 0.8925233644859814
# Test Accuracy at gamma 0.09: 0.8913043478260869
#
#
# Training Accuracy at gamma 0.1: 0.8940809968847352
# Test Accuracy at gamma 0.1: 0.8876811594202898
#
#
# Training Accuracy at gamma 0.11: 0.897196261682243
# Test Accuracy at gamma 0.11: 0.8876811594202898
#
#
# Training Accuracy at gamma 0.12: 0.9034267912772586
# Test Accuracy at gamma 0.12: 0.8876811594202898
#
#
# Training Accuracy at gamma 0.13: 0.9080996884735203
# Test Accuracy at gamma 0.13: 0.8876811594202898
#
#
# Training Accuracy at gamma 0.14: 0.9096573208722741
# Test Accuracy at gamma 0.14: 0.8876811594202898
#
#
# Training Accuracy at gamma 0.15: 0.9127725856697819
# Test Accuracy at gamma 0.15: 0.8840579710144928
#
#
# Training Accuracy at gamma 0.16: 0.9174454828660437
# Test Accuracy at gamma 0.16: 0.8804347826086957
#
#
# Training Accuracy at gamma 0.17: 0.9190031152647975
# Test Accuracy at gamma 0.17: 0.8768115942028986
#
#
# Training Accuracy at gamma 0.18: 0.9190031152647975
# Test Accuracy at gamma 0.18: 0.8731884057971014
#
#
# Training Accuracy at gamma 0.19: 0.9221183800623053
# Test Accuracy at gamma 0.19: 0.8768115942028986
#
#
# Training Accuracy at gamma 0.2: 0.9252336448598131
# Test Accuracy at gamma 0.2: 0.8768115942028986
#
#
# Training Accuracy at gamma 0.21: 0.9252336448598131
# Test Accuracy at gamma 0.21: 0.8768115942028986
#
#
# Training Accuracy at gamma 0.22: 0.926791277258567
# Test Accuracy at gamma 0.22: 0.8804347826086957
#
#
# Training Accuracy at gamma 0.23: 0.9299065420560748
# Test Accuracy at gamma 0.23: 0.8804347826086957
#
#
# Training Accuracy at gamma 0.24: 0.9361370716510904
# Test Accuracy at gamma 0.24: 0.8768115942028986
#
#
# Training Accuracy at gamma 0.25: 0.9392523364485982
# Test Accuracy at gamma 0.25: 0.8768115942028986
#
#
# Training Accuracy at gamma 0.26: 0.940809968847352
# Test Accuracy at gamma 0.26: 0.8768115942028986
#
#
# Training Accuracy at gamma 0.27: 0.940809968847352
# Test Accuracy at gamma 0.27: 0.8840579710144928
#
#
# Training Accuracy at gamma 0.28: 0.9439252336448598
# Test Accuracy at gamma 0.28: 0.8840579710144928
#
#
# Training Accuracy at gamma 0.29: 0.9454828660436138
# Test Accuracy at gamma 0.29: 0.8804347826086957
#
#
# Training Accuracy at gamma 0.3: 0.9485981308411215
# Test Accuracy at gamma 0.3: 0.8768115942028986
#
#
# Training Accuracy at gamma 0.31: 0.9485981308411215
# Test Accuracy at gamma 0.31: 0.8768115942028986
#
#
# Training Accuracy at gamma 0.32: 0.9517133956386293
# Test Accuracy at gamma 0.32: 0.8731884057971014
#
#
# Training Accuracy at gamma 0.33: 0.9548286604361371
# Test Accuracy at gamma 0.33: 0.8695652173913043
#
#
# Training Accuracy at gamma 0.34: 0.956386292834891
# Test Accuracy at gamma 0.34: 0.8695652173913043
#
#
# Training Accuracy at gamma 0.35: 0.9595015576323987
# Test Accuracy at gamma 0.35: 0.8731884057971014
#
#
# Training Accuracy at gamma 0.36: 0.9595015576323987
# Test Accuracy at gamma 0.36: 0.8695652173913043
#
#
# Training Accuracy at gamma 0.37: 0.9610591900311527
# Test Accuracy at gamma 0.37: 0.8659420289855072
#
#
# Training Accuracy at gamma 0.38: 0.9610591900311527
# Test Accuracy at gamma 0.38: 0.8623188405797102
#
#
# Training Accuracy at gamma 0.39: 0.9610591900311527
# Test Accuracy at gamma 0.39: 0.8586956521739131
#
#
# Training Accuracy at gamma 0.4: 0.9641744548286605
# Test Accuracy at gamma 0.4: 0.8586956521739131
#
#
# Training Accuracy at gamma 0.41: 0.9641744548286605
# Test Accuracy at gamma 0.41: 0.8586956521739131
#
#
# Training Accuracy at gamma 0.42: 0.9657320872274143
# Test Accuracy at gamma 0.42: 0.8586956521739131
#
#
# Training Accuracy at gamma 0.43: 0.9672897196261683
# Test Accuracy at gamma 0.43: 0.855072463768116
#
#
# Training Accuracy at gamma 0.44: 0.9672897196261683
# Test Accuracy at gamma 0.44: 0.855072463768116
#
#
# Training Accuracy at gamma 0.45: 0.9672897196261683
# Test Accuracy at gamma 0.45: 0.855072463768116
#
#
# Training Accuracy at gamma 0.46: 0.9704049844236761
# Test Accuracy at gamma 0.46: 0.855072463768116
#
#
# Training Accuracy at gamma 0.47: 0.9704049844236761
# Test Accuracy at gamma 0.47: 0.855072463768116
#
#
# Training Accuracy at gamma 0.48: 0.9704049844236761
# Test Accuracy at gamma 0.48: 0.855072463768116
#
#
# Training Accuracy at gamma 0.49: 0.9719626168224299
# Test Accuracy at gamma 0.49: 0.8514492753623188
#
#
# Training Accuracy at gamma 0.5: 0.9719626168224299
# Test Accuracy at gamma 0.5: 0.8478260869565217
#
#
# Training Accuracy at gamma 0.51: 0.9719626168224299
# Test Accuracy at gamma 0.51: 0.8478260869565217
#
#
# Training Accuracy at gamma 0.52: 0.9719626168224299
# Test Accuracy at gamma 0.52: 0.8442028985507246
#
#
# Training Accuracy at gamma 0.53: 0.9735202492211839
# Test Accuracy at gamma 0.53: 0.8442028985507246
#
#
# Training Accuracy at gamma 0.54: 0.9766355140186916
# Test Accuracy at gamma 0.54: 0.8405797101449275
#
#
# Training Accuracy at gamma 0.55: 0.9766355140186916
# Test Accuracy at gamma 0.55: 0.8333333333333334
#
#
# Training Accuracy at gamma 0.56: 0.9781931464174455
# Test Accuracy at gamma 0.56: 0.8297101449275363
#
#
# Training Accuracy at gamma 0.57: 0.9781931464174455
# Test Accuracy at gamma 0.57: 0.8260869565217391
#
#
# Training Accuracy at gamma 0.58: 0.9781931464174455
# Test Accuracy at gamma 0.58: 0.8260869565217391
#
#
# Training Accuracy at gamma 0.59: 0.9797507788161994
# Test Accuracy at gamma 0.59: 0.822463768115942
#
#
# Training Accuracy at gamma 0.6: 0.9797507788161994
# Test Accuracy at gamma 0.6: 0.8188405797101449
#
#
# Training Accuracy at gamma 0.61: 0.9797507788161994
# Test Accuracy at gamma 0.61: 0.8188405797101449
#
#
# Training Accuracy at gamma 0.62: 0.9828660436137072
# Test Accuracy at gamma 0.62: 0.8188405797101449
#
#
# Training Accuracy at gamma 0.63: 0.985981308411215
# Test Accuracy at gamma 0.63: 0.8152173913043478
#
#
# Training Accuracy at gamma 0.64: 0.985981308411215
# Test Accuracy at gamma 0.64: 0.8115942028985508
#
#
# Training Accuracy at gamma 0.65: 0.985981308411215
# Test Accuracy at gamma 0.65: 0.8079710144927537
#
#
# Training Accuracy at gamma 0.66: 0.985981308411215
# Test Accuracy at gamma 0.66: 0.8079710144927537
#
#
# Training Accuracy at gamma 0.67: 0.985981308411215
# Test Accuracy at gamma 0.67: 0.8079710144927537
#
#
# Training Accuracy at gamma 0.68: 0.985981308411215
# Test Accuracy at gamma 0.68: 0.8079710144927537
#
#
# Training Accuracy at gamma 0.69: 0.985981308411215
# Test Accuracy at gamma 0.69: 0.8079710144927537
#
#
# Training Accuracy at gamma 0.7: 0.985981308411215
# Test Accuracy at gamma 0.7: 0.8043478260869565
#
#
# Training Accuracy at gamma 0.71: 0.9875389408099688
# Test Accuracy at gamma 0.71: 0.8007246376811594
#
#
# Training Accuracy at gamma 0.72: 0.9875389408099688
# Test Accuracy at gamma 0.72: 0.8007246376811594
#
#
# Training Accuracy at gamma 0.73: 0.9875389408099688
# Test Accuracy at gamma 0.73: 0.8007246376811594
#
#
# Training Accuracy at gamma 0.74: 0.9875389408099688
# Test Accuracy at gamma 0.74: 0.8007246376811594
#
#
# Training Accuracy at gamma 0.75: 0.9875389408099688
# Test Accuracy at gamma 0.75: 0.8007246376811594
#
#
# Training Accuracy at gamma 0.76: 0.9875389408099688
# Test Accuracy at gamma 0.76: 0.7971014492753623
#
#
# Training Accuracy at gamma 0.77: 0.9890965732087228
# Test Accuracy at gamma 0.77: 0.7898550724637681
#
#
# Training Accuracy at gamma 0.78: 0.9890965732087228
# Test Accuracy at gamma 0.78: 0.7862318840579711
#
#
# Training Accuracy at gamma 0.79: 0.9890965732087228
# Test Accuracy at gamma 0.79: 0.7862318840579711
#
#
# Training Accuracy at gamma 0.8: 0.9890965732087228
# Test Accuracy at gamma 0.8: 0.7862318840579711
#
#
# Training Accuracy at gamma 0.81: 0.9890965732087228
# Test Accuracy at gamma 0.81: 0.7862318840579711
#
#
# Training Accuracy at gamma 0.82: 0.9890965732087228
# Test Accuracy at gamma 0.82: 0.7862318840579711
#
#
# Training Accuracy at gamma 0.83: 0.9890965732087228
# Test Accuracy at gamma 0.83: 0.7862318840579711
#
#
# Training Accuracy at gamma 0.84: 0.9890965732087228
# Test Accuracy at gamma 0.84: 0.7789855072463768
#
#
# Training Accuracy at gamma 0.85: 0.9890965732087228
# Test Accuracy at gamma 0.85: 0.7789855072463768
#
#
# Training Accuracy at gamma 0.86: 0.9890965732087228
# Test Accuracy at gamma 0.86: 0.7789855072463768
#
#
# Training Accuracy at gamma 0.87: 0.9890965732087228
# Test Accuracy at gamma 0.87: 0.7753623188405797
#
#
# Training Accuracy at gamma 0.88: 0.9890965732087228
# Test Accuracy at gamma 0.88: 0.7753623188405797
#
#
# Training Accuracy at gamma 0.89: 0.9890965732087228
# Test Accuracy at gamma 0.89: 0.7753623188405797
#
#
# Training Accuracy at gamma 0.9: 0.9890965732087228
# Test Accuracy at gamma 0.9: 0.7681159420289855
#
#
# Training Accuracy at gamma 0.91: 0.9890965732087228
# Test Accuracy at gamma 0.91: 0.7644927536231884
#
#
# Training Accuracy at gamma 0.92: 0.9890965732087228
# Test Accuracy at gamma 0.92: 0.7681159420289855
#
#
# Training Accuracy at gamma 0.93: 0.9890965732087228
# Test Accuracy at gamma 0.93: 0.7681159420289855
#
#
# Training Accuracy at gamma 0.94: 0.9890965732087228
# Test Accuracy at gamma 0.94: 0.7681159420289855
#
#
# Training Accuracy at gamma 0.95: 0.9890965732087228
# Test Accuracy at gamma 0.95: 0.7681159420289855
#
#
# Training Accuracy at gamma 0.96: 0.9890965732087228
# Test Accuracy at gamma 0.96: 0.7681159420289855
#
#
# Training Accuracy at gamma 0.97: 0.9890965732087228
# Test Accuracy at gamma 0.97: 0.7681159420289855
#
#
# Training Accuracy at gamma 0.98: 0.9890965732087228
# Test Accuracy at gamma 0.98: 0.7681159420289855
#
#
# Training Accuracy at gamma 0.99: 0.9890965732087228
# Test Accuracy at gamma 0.99: 0.7681159420289855

# %%
# Based on what i observed above the model fit best with rbf kernel and gamma = 0.09

model = SVC(kernel='rbf', gamma= 0.09)
model.fit(X_train, y_train)

print(f"Training Accuracy at gamma 0.09: {model.score(X_train, y_train)}")
print(f"Test Accuracy at gamma 0.09: {model.score(X_test, y_test)}\n\n")
# Out:
# Training Accuracy at gamma 0.99: 0.8925233644859814
# Test Accuracy at gamma 0.99: 0.8913043478260869

# %%
i = 9
print(f'Model predict patient {i+1}: {model.predict(X_test[i].reshape(1, -1))}')
print(f'The ground truth is {y_test[i]}')
# Out:
# Model predict patient 10: [1]
# The ground truth is 1
